# %%
import sqlite3

# %%
conn = sqlite3.connect('sales.db')
curr = conn.cursor()

# %%
curr.execute('''
    SELECT * FROM sales;
''')
rows = curr.fetchall()

# %%
import pandas as pd
pd.DataFrame(rows).iloc[-1]
# Out:
# 0                                            2026-01-14
# 1                                       17:54:30.506672
# 2     Apple MacBook Air M4 - (16 GB/256 GB SSD/macOS...
# 3                                               99900.0
# 4                                               91490.0
# 5                                                   8.0
# 6                                                   4.7
# 7                                                   149
# 8                                                  2212
# 9                                             Available
# 10                                 TREASURE HAUL ONLINE
# 11                                                  4.6
# 12    https://www.flipkart.com/apple-macbook-air-m4-...
# Name: 13, dtype: object
